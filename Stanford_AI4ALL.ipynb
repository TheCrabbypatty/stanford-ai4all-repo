# %% [markdown]
# <a href="https://colab.research.google.com/github/TheCrabbypatty/stanford-ai4all-repo/blob/main/Stanford_AI4ALL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q pybullet opencv-python matplotlib scikit-learn
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.5/80.5 MB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done

# %%
# !pip install -q pybullet opencv-python matplotlib numpy
